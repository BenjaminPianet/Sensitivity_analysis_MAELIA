# %% [markdown]
# # Batch MAELIA — Plan d'Expérience SMT
#
# Ce notebook :
# 1. Génère un plan d'expérience hiérarchique via **SMT** (espace de conception de `Try_MAELIA.ipynb`).
# 2. Convertit chaque point en fichier `dateDose.csv` compatible MAELIA.
# 3. Lance les simulations GAMA en mode **headless** (sans GUI).
# 4. Collecte et visualise les sorties.
#
# **Suivi des logs en temps réel** — ouvrir un terminal et lancer :
# ```bash
# tail -f /tmp/gama_smt.log
# ```

# %% [markdown]
# ## 0. Imports & configuration

# %%
import os, sys, subprocess, time, io, warnings, shutil
from pathlib import Path
from datetime import date, timedelta
import xml.etree.ElementTree as ET

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# SMT
from smt.design_space import FloatVariable, OrdinalVariable, CategoricalVariable
from smt_design_space_ext import AdsgDesignSpaceImpl

warnings.filterwarnings('ignore')
plt.rcParams.update({'figure.dpi': 120, 'savefig.bbox': 'tight'})

# ─── Chemins ──────────────────────────────────────────────────────────────────
GAMA_HEADLESS = '/Applications/Gama.app/Contents/headless/gama-headless.sh'
MAELIA_ROOT   = Path('/Users/benjamin/Workspace_GAMA/MAELIA')
MODEL_PATH    = MAELIA_ROOT / 'models/main/launcherBase.gaml'
LOG_DIR       = MAELIA_ROOT / 'models/main/log'
VARIANTS_DIR  = MAELIA_ROOT / 'includes/terrainTest/modeleAgricole/agriculteurs/variants_SMT'
BLOC_DONNEES  = MAELIA_ROOT / 'includes/terrainTest/modeleAgricole/blocsDonnees.csv'
XML_DIR       = Path('/tmp/maelia_smt_xml')
GAMA_LOG      = Path('/tmp/gama_smt.log')

# ─── Paramètres de simulation ─────────────────────────────────────────────────
ANNEE_DEBUT   = 2019
NB_ANNEES     = 12             # couvre 2015-2030 (campagne blé 2015 → récolte 2016...)
ANNEES_DOSE   = list(range(2019, 2031))        # campagnes de 2015 à 2030
FINAL_STEP    = 1200
CROP          = 'ble'
NOM_DECOUPAGE = 'terrainTest'
CHEMIN_RACINE = str(MAELIA_ROOT) + '/'

# ─── Liste de toutes les parcelles du territoire ──────────────────────────────
_all_parcs = []
with open(BLOC_DONNEES) as _f:
    for _line in _f:
        _parts = [_p.strip() for _p in _line.strip().split(';') if _p.strip()]
        if len(_parts) >= 2:
            _all_parcs.append(_parts[1])   # parcelle principale
        if len(_parts) >= 3:
            _all_parcs.append(_parts[2])   # variante copie_*
# Filtrer strictement pour ne garder que la parcelle beauce_5_1.
# Le match exact évite de récupérer accidentellement beauce_50, beauce_51, etc.
ALL_PARCELLES = [p for p in _all_parcs if p == 'beauce_5_1']
if not ALL_PARCELLES: ALL_PARCELLES = ['beauce_5_1'] # Fallback de sécurité
print(f'Territoire : {len(ALL_PARCELLES)} parcelles (Cible: {ALL_PARCELLES}) chargées depuis blocsDonnees.csv')

# ─── Taille du DOE ────────────────────────────────────────────────────────────
N_SIMU = 100
N_DOE  = N_SIMU * len(ALL_PARCELLES)  # Un point unique par parcelle et par simulation

# ─── Création des dossiers ────────────────────────────────────────────────────
XML_DIR.mkdir(parents=True, exist_ok=True)
VARIANTS_DIR.mkdir(parents=True, exist_ok=True)

# ─── Nettoyage des anciens fichiers SMT ───────────────────────────────────────
old_dirs = sorted(LOG_DIR.glob('terrainTest_smt_*'))
if old_dirs:
    print(f'Nettoyage de {len(old_dirs)} anciens répertoire(s) de sortie SMT...')
    for d in old_dirs:
        shutil.rmtree(d)
    print('  OK.')

old_csvs = sorted(VARIANTS_DIR.glob('dateDose_smt_*.csv'))
if old_csvs:
    print(f'Nettoyage de {len(old_csvs)} anciens fichier(s) dateDose SMT...')
    for f in old_csvs:
        f.unlink()
    print('  OK.')

print('Configuration OK')
print(f'  Culture       : {CROP}')
print(f'  Campagne      : {ANNEES_DOSE}')
print(f'  Simulation    : {N_SIMU} runs')
print(f'  Parcelles     : {len(ALL_PARCELLES)}')
print(f'  Points DOE    : {N_DOE} (LHS distribué)')
print()
print('─' * 55)
print('Pour suivre les logs GAMA dans un terminal :')
print(f'  tail -f {GAMA_LOG}')
print('─' * 55)
# Out:
# Territoire : 1 parcelles (Cible: ['beauce_5_1']) chargées depuis blocsDonnees.csv
# Nettoyage de 100 anciens fichier(s) dateDose SMT...
#   OK.
# Configuration OK
#   Culture       : ble
#   Campagne      : [2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030]
#   Simulation    : 100 runs
#   Parcelles     : 1
#   Points DOE    : 100 (LHS distribué)
#
# ───────────────────────────────────────────────────────
# Pour suivre les logs GAMA dans un terminal :
#   tail -f /tmp/gama_smt.log
# ───────────────────────────────────────────────────────

# %% [markdown]
# ## 1. Espace de conception SMT
#
# Reprise de l'espace de conception hiérarchique défini dans `Try_MAELIA.ipynb` (26 variables : 14 discrètes/catégorielles + 12 continues).

# %%
# ─── Types de préparation et de fertilisation ─────────────────────────────────
prepa_types = ['Labour', 'Preparation du lit de semence', 'Déchaumage', 'Roulage']
ferti_types = ['N_solution', 'AN', 'mineral', 'urea']

# Plan SMT/ADSG utilisé pour les simulations MAELIA.
# Les variables calendaires sont désormais exprimées en jours de l'année absolus,
# sauf Delta_PREPA_Semis qui reste un décalage négatif appliqué au semis.
SMT_FEATURES = [
    'n_ferti', 'has_prepa', 'nb_prepa', 'prepa_1',
    'nb_f1', 'type_f1_1', 'nb_f2', 'type_f2_1', 'nb_f3', 'type_f3_1',
    'prepa_2', 'type_f1_2', 'type_f2_2', 'type_f3_2',
    'Date_Semis', 'Delta_PREPA_Semis', 'Date_F1', 'Date_F2', 'Date_F3', 'Date_Recolte',
    'Dose_F1_1', 'Dose_F1_2', 'Dose_F2_1', 'Dose_F2_2', 'Dose_F3_1', 'Dose_F3_2',
]
SMT_CATEGORICAL = SMT_FEATURES[:14]
SMT_CONTINUOUS = SMT_FEATURES[14:]

agri_design_space = AdsgDesignSpaceImpl(
    design_variables=[
        # --- Bloc discret avec tags uniques ---
        OrdinalVariable(['0_ferti', '1_ferti', '2_ferti', '3_ferti']),  # 0: n_ferti
        OrdinalVariable(['Non_prepa', 'Oui_prepa']),                    # 1: has_prepa
        OrdinalVariable(['1_prepa', '2_prepa']),                        # 2: nb_prepa
        CategoricalVariable([p + '_p1' for p in prepa_types]),          # 3: prepa_1
        CategoricalVariable([p + '_p2' for p in prepa_types]),          # 4: prepa_2

        OrdinalVariable(['1_f1', '2_f1']),                              # 5: nb_f1
        CategoricalVariable([f + '_f11' for f in ferti_types]),         # 6: type_f1_1
        CategoricalVariable([f + '_f12' for f in ferti_types]),         # 7: type_f1_2

        OrdinalVariable(['1_f2', '2_f2']),                              # 8: nb_f2
        CategoricalVariable([f + '_f21' for f in ferti_types]),         # 9: type_f2_1
        CategoricalVariable([f + '_f22' for f in ferti_types]),         # 10: type_f2_2

        OrdinalVariable(['1_f3', '2_f3']),                              # 11: nb_f3
        CategoricalVariable([f + '_f31' for f in ferti_types]),         # 12: type_f3_1
        CategoricalVariable([f + '_f32' for f in ferti_types]),         # 13: type_f3_2

        # --- Bloc continu ---
        FloatVariable(45, 106),     # 14: Date_Semis
        FloatVariable(-44, -4),     # 15: Delta_PREPA_Semis
        FloatVariable(106, 323),    # 16: Date_F1
        FloatVariable(210, 323),    # 17: Date_F2
        FloatVariable(240, 323),    # 18: Date_F3
        FloatVariable(323, 384),    # 19: Date_Recolte
        FloatVariable(10, 100),     # 20: Dose_F1_1
        FloatVariable(10, 100),     # 21: Dose_F1_2
        FloatVariable(10, 100),     # 22: Dose_F2_1
        FloatVariable(10, 100),     # 23: Dose_F2_2
        FloatVariable(10, 100),     # 24: Dose_F3_1
        FloatVariable(10, 100),     # 25: Dose_F3_2
    ]
)

# Hiérarchie d'activation ADSG.
agri_design_space.declare_decreed_var(decreed_var=2,  meta_var=1, meta_value=['Oui_prepa'])
agri_design_space.declare_decreed_var(decreed_var=3,  meta_var=1, meta_value=['Oui_prepa'])
agri_design_space.declare_decreed_var(decreed_var=15, meta_var=1, meta_value=['Oui_prepa'])
agri_design_space.declare_decreed_var(decreed_var=4,  meta_var=2, meta_value=['2_prepa'])

agri_design_space.declare_decreed_var(decreed_var=16, meta_var=0, meta_value=['1_ferti', '2_ferti', '3_ferti'])
agri_design_space.declare_decreed_var(decreed_var=5,  meta_var=0, meta_value=['1_ferti', '2_ferti', '3_ferti'])
agri_design_space.declare_decreed_var(decreed_var=6,  meta_var=0, meta_value=['1_ferti', '2_ferti', '3_ferti'])
agri_design_space.declare_decreed_var(decreed_var=20, meta_var=0, meta_value=['1_ferti', '2_ferti', '3_ferti'])
agri_design_space.declare_decreed_var(decreed_var=7,  meta_var=5, meta_value=['2_f1'])
agri_design_space.declare_decreed_var(decreed_var=21, meta_var=5, meta_value=['2_f1'])

agri_design_space.declare_decreed_var(decreed_var=17, meta_var=0, meta_value=['2_ferti', '3_ferti'])
agri_design_space.declare_decreed_var(decreed_var=8,  meta_var=0, meta_value=['2_ferti', '3_ferti'])
agri_design_space.declare_decreed_var(decreed_var=9,  meta_var=0, meta_value=['2_ferti', '3_ferti'])
agri_design_space.declare_decreed_var(decreed_var=22, meta_var=0, meta_value=['2_ferti', '3_ferti'])
agri_design_space.declare_decreed_var(decreed_var=10, meta_var=8, meta_value=['2_f2'])
agri_design_space.declare_decreed_var(decreed_var=23, meta_var=8, meta_value=['2_f2'])

agri_design_space.declare_decreed_var(decreed_var=18, meta_var=0, meta_value=['3_ferti'])
agri_design_space.declare_decreed_var(decreed_var=11, meta_var=0, meta_value=['3_ferti'])
agri_design_space.declare_decreed_var(decreed_var=12, meta_var=0, meta_value=['3_ferti'])
agri_design_space.declare_decreed_var(decreed_var=24, meta_var=0, meta_value=['3_ferti'])
agri_design_space.declare_decreed_var(decreed_var=13, meta_var=11, meta_value=['2_f3'])
agri_design_space.declare_decreed_var(decreed_var=25, meta_var=11, meta_value=['2_f3'])

# Contraintes catégorielles conservées. Les contraintes numériques d'ordre F1/F2/F3
# sont appliquées explicitement lors de l'écriture des opérations dateDose.
agri_design_space.add_value_constraint(var1=4, value1=['Labour_p2'], var2=2, value2=['2_prepa'])
agri_design_space.add_value_constraint(var1=3, value1=['Labour_p1'], var2=2, value2=['2_prepa'])


PREPA_TYPE_ALIASES = {
    'Preparationdulitdesemence': 'Preparation du lit de semence',
}

def normalize_prepa_type(value):
    return PREPA_TYPE_ALIASES.get(value, value)

def parse_smt_row(row_data):
    """Analyse une ligne décodée par SMT en cherchant les tags uniques."""
    parsed = {
        'n_ferti': 0, 'has_prepa': False, 'nb_prepa': 1,
        'nb_f1': 1, 'nb_f2': 1, 'nb_f3': 1,
        'prepa_t1': '-', 'prepa_t2': '-',
        'f1_t1': '-', 'f1_t2': '-', 'f2_t1': '-', 'f2_t2': '-', 'f3_t1': '-', 'f3_t2': '-',
        'floats': [],
    }
    values = list(row_data.values()) if isinstance(row_data, dict) else row_data

    for val in values:
        if isinstance(val, (float, int, np.floating, np.integer)):
            parsed['floats'].append(float(val))
        elif isinstance(val, str):
            if '_ferti' in val:
                parsed['n_ferti'] = int(val[0])
            elif val in ['Oui_prepa', 'Non_prepa']:
                parsed['has_prepa'] = (val == 'Oui_prepa')
            elif val in ['1_prepa', '2_prepa']:
                parsed['nb_prepa'] = int(val[0])
            elif '_p1' in val:
                parsed['prepa_t1'] = normalize_prepa_type(val.replace('_p1', ''))
            elif '_p2' in val:
                parsed['prepa_t2'] = normalize_prepa_type(val.replace('_p2', ''))
            elif val in ['1_f1', '2_f1']:
                parsed['nb_f1'] = int(val[0])
            elif '_f11' in val:
                parsed['f1_t1'] = val.replace('_f11', '')
            elif '_f12' in val:
                parsed['f1_t2'] = val.replace('_f12', '')
            elif val in ['1_f2', '2_f2']:
                parsed['nb_f2'] = int(val[0])
            elif '_f21' in val:
                parsed['f2_t1'] = val.replace('_f21', '')
            elif '_f22' in val:
                parsed['f2_t2'] = val.replace('_f22', '')
            elif val in ['1_f3', '2_f3']:
                parsed['nb_f3'] = int(val[0])
            elif '_f31' in val:
                parsed['f3_t1'] = val.replace('_f31', '')
            elif '_f32' in val:
                parsed['f3_t2'] = val.replace('_f32', '')
    return parsed


def normalized_floats(parsed, default=50.0):
    fl = list(parsed['floats'])
    while len(fl) < 12:
        fl.append(default)
    return fl


def ordered_fertilisation_dates(parsed, fl):
    """Retourne des dates F1/F2/F3 strictement ordonnées pour MAELIA."""
    dates = {'f1': None, 'f2': None, 'f3': None}
    if parsed['n_ferti'] >= 1:
        dates['f1'] = int(round(fl[2]))
    if parsed['n_ferti'] >= 2:
        dates['f2'] = max(int(round(fl[3])), dates['f1'] + 1)
    if parsed['n_ferti'] >= 3:
        dates['f3'] = max(int(round(fl[4])), dates['f2'] + 1)
    return dates


def extract_table_from_smt(x_array, dsg_space):
    rows = []
    decoded_data = dsg_space.decode_values(x_array)

    for row_data in decoded_data:
        p = parse_smt_row(row_data)
        fl = normalized_floats(p)
        ferti_dates = ordered_fertilisation_dates(p, fl)

        semi = int(round(fl[0]))
        recolte = int(round(fl[5]))
        prepa_date = int(round(semi + fl[1])) if p['has_prepa'] else None
        p2 = p['prepa_t2'] if p['has_prepa'] and p['nb_prepa'] == 2 else '-'

        if not p['has_prepa']:
            p['prepa_t1'] = '-'

        if p['n_ferti'] >= 1:
            f1_d1 = round(fl[6], 1)
            f1_t2 = p['f1_t2'] if p['nb_f1'] == 2 else '-'
            f1_d2 = round(fl[7], 1) if p['nb_f1'] == 2 else '-'
        else:
            p['f1_t1'] = f1_d1 = f1_t2 = f1_d2 = '-'

        if p['n_ferti'] >= 2:
            f2_d1 = round(fl[8], 1)
            f2_t2 = p['f2_t2'] if p['nb_f2'] == 2 else '-'
            f2_d2 = round(fl[9], 1) if p['nb_f2'] == 2 else '-'
        else:
            p['f2_t1'] = f2_d1 = f2_t2 = f2_d2 = '-'

        if p['n_ferti'] >= 3:
            f3_d1 = round(fl[10], 1)
            f3_t2 = p['f3_t2'] if p['nb_f3'] == 2 else '-'
            f3_d2 = round(fl[11], 1) if p['nb_f3'] == 2 else '-'
        else:
            p['f3_t1'] = f3_d1 = f3_t2 = f3_d2 = '-'

        rows.append({
            'n_ferti': p['n_ferti'], 'has_prepa': 'Oui' if p['has_prepa'] else 'Non',
            'Semi': semi,
            'PREPA_Date': prepa_date if prepa_date is not None else '-',
            'PREPA_Type_1': p['prepa_t1'], 'PREPA_Type_2': p2,
            'Ferti_1': ferti_dates['f1'] if ferti_dates['f1'] is not None else '-',
            'F1_Type_1': p['f1_t1'], 'F1_Dose_1': f1_d1, 'F1_Type_2': f1_t2, 'F1_Dose_2': f1_d2,
            'Ferti_2': ferti_dates['f2'] if ferti_dates['f2'] is not None else '-',
            'F2_Type_1': p['f2_t1'], 'F2_Dose_1': f2_d1, 'F2_Type_2': f2_t2, 'F2_Dose_2': f2_d2,
            'Ferti_3': ferti_dates['f3'] if ferti_dates['f3'] is not None else '-',
            'F3_Type_1': p['f3_t1'], 'F3_Dose_1': f3_d1, 'F3_Type_2': f3_t2, 'F3_Dose_2': f3_d2,
            'Recolte': recolte,
        })

    return pd.DataFrame(rows)

# %% [markdown]
# ## 2. Génération du plan d'expérience (DOE)

# %%
print(f'Génération de {N_DOE} points LHS hiérarchiques (SMT ADSG)...')
result = agri_design_space._sample_valid_x(N_DOE)
xt, is_acting_t = result[0], result[1]
print(f'Matrice DOE : {xt.shape[0]} × {xt.shape[1]} variables')
print()

doe_display = extract_table_from_smt(xt, agri_design_space)
print(f'Aperçu du plan d\'expérience (N={N_DOE}) :')
display(doe_display)
# Out:
# Génération de 100 points LHS hiérarchiques (SMT ADSG)...
# Matrice DOE : 100 × 26 variables
#
# Aperçu du plan d'expérience (N=100) :
#     n_ferti has_prepa  Semi PREPA_Date               PREPA_Type_1  \
# 0         0       Non    56          -                          -
# 1         1       Oui   103         90  Preparationdulitdesemence
# 2         0       Non    56          -                          -
# 3         0       Non   102          -                          -
# 4         3       Oui    72         35                     Labour
# ..      ...       ...   ...        ...                        ...
# 95        2       Oui    78         67                     Labour
# 96        2       Oui    70         36                     Labour
# 97        0       Non    57          -                          -
# 98        1       Oui    81         48                    Roulage
# 99        3       Oui    72         38  Preparationdulitdesemence
#
#                  PREPA_Type_2 Ferti_1   F1_Type_1 F1_Dose_1   F1_Type_2  ...  \
# 0                           -       -           -         -           -  ...
# 1   Preparationdulitdesemence     233          AN      79.8           -  ...
# 2                           -       -           -         -           -  ...
# 3                           -       -           -         -           -  ...
# 4                           -     262          AN      20.6           -  ...
# ..                        ...     ...         ...       ...         ...  ...
# 95                          -     292  N_solution      97.1           -  ...
# 96                          -     114     mineral      44.3  N_solution  ...
# 97                          -       -           -         -           -  ...
# 98  Preparationdulitdesemence     158          AN      81.7        urea  ...
# 99                          -     186          AN      15.2           -  ...
#
#      F2_Type_1 F2_Dose_1 F2_Type_2 F2_Dose_2 Ferti_3   F3_Type_1 F3_Dose_1  \
# 0            -         -         -         -       -           -         -
# 1            -         -         -         -       -           -         -
# 2            -         -         -         -       -           -         -
# 3            -         -         -         -       -           -         -
# 4         urea      14.4         -         -     309  N_solution      64.9
# ..         ...       ...       ...       ...     ...         ...       ...
# 95  N_solution      96.9         -         -       -           -         -
# 96  N_solution      83.7         -         -       -           -         -
# 97           -         -         -         -       -           -         -
# 98           -         -         -         -       -           -         -
# 99          AN      64.4         -         -     322     mineral      78.8
#
#    F3_Type_2 F3_Dose_2 Recolte
# 0          -         -     343
# 1          -         -     347
# 2          -         -     341
# 3          -         -     376
# 4          -         -     359
# ..       ...       ...     ...
# 95         -         -     372
# 96         -         -     355
# 97         -         -     369
# 98         -         -     343
# 99         -         -     329
#
# [100 rows x 22 columns]

# %% [markdown]
# ## 3. Génération des fichiers `dateDose.csv`
#
# Chaque point du DOE est converti en fichier `dateDose_smt_XXX.csv` au format MAELIA :
# - **PREPA** : `fl[1]` jours **avant** le semis (préparation du sol).
# - **SEMIS** : jour `fl[0]` de l'année.
# - **FERTI_Min** : `fl[2]` jours après semis (F1), puis `fl[3]` jours pour F2, `fl[4]` pour F3.
# - **RECOLTE** : `fl[5]` jours après la dernière opération.

# %%
PREPA_DEPTHS = {
    'Labour': '24',
    'Preparation du lit de semence': '10',
    'Déchaumage': '',
    'Roulage': '',
}

COLS = ['Trait', 'nom_MAELIA', 'plant_sem', 'annee_deb',
        'id_operation', 'ordre_op', 'DATE', 'PROF', 'TYPE', 'DOSE']

HARVEST_BUFFER_DAYS = 7
MIN_DAYS_LAST_OP_TO_HARVEST = 1

def days_in_year(year):
    # Longueur de la campagne agricole démarrant le 1er août de `year`.
    return (date(year + 1, 8, 1) - date(year, 8, 1)).days

def doy_to_date_str(year, doy):
    # Les jours du plan SMT sont des jours de campagne : 1 = 1er août de `year`.
    campaign_start = date(year, 8, 1)
    return (campaign_start + timedelta(days=int(doy) - 1)).strftime('%d/%m/%Y')

def parse_date_str(value):
    return pd.to_datetime(value, dayfirst=True).date()

def safe_f(val, default=50.0):
    try:
        v = float(val)
        return default if v != v else v
    except (TypeError, ValueError):
        return default

def validate_datedose_rows(rows):
    """Détecte les calendriers qui feraient planter agriculteurDateDose.gaml."""
    order = {'RECOLTE': 0, 'PREPA': 1, 'SEMIS': 2, 'FERTI_Min': 3}
    by_parcelle = {}
    issues = []
    for row in rows:
        by_parcelle.setdefault(row['Trait'], []).append(row)

    for parcelle_id, parcelle_ops in by_parcelle.items():
        culture_en_place = False
        sorted_ops = sorted(
            parcelle_ops,
            key=lambda row: (parse_date_str(row['DATE']),
                             order.get(row['id_operation'], 99),
                             str(row.get('ordre_op', ''))),
        )
        for row in sorted_ops:
            op = row['id_operation']
            day = row['DATE']
            campagne = int(row['annee_deb'])
            op_date = parse_date_str(day)
            campaign_start = date(campagne, 8, 1)
            if op_date < campaign_start:
                issues.append(
                    f'{parcelle_id} campagne {campagne}: {op} le {day} avant le démarrage de campagne ({campaign_start.strftime("%d/%m/%Y")})'
                )
            if op == 'SEMIS':
                if culture_en_place:
                    issues.append(f'{parcelle_id} campagne {campagne}: SEMIS le {day} alors qu’une culture est déjà en place')
                culture_en_place = True
            elif op == 'RECOLTE':
                if not culture_en_place:
                    issues.append(f'{parcelle_id} campagne {campagne}: RECOLTE le {day} sans culture en place')
                culture_en_place = False
            elif op == 'FERTI_Min':
                if not culture_en_place:
                    issues.append(f'{parcelle_id} campagne {campagne}: FERTI_Min le {day} sans culture en place')
            elif op == 'PREPA':
                pass
            else:
                issues.append(f'{parcelle_id} campagne {campagne}: opération inconnue {op}')
    return issues

def generate_ops_for_parcelle(point_idx, parcelle_id, years):
    """Génère les opérations pour un SEUL point DOE appliqué à une SEULE parcelle."""
    decoded = agri_design_space.decode_values(xt[point_idx:point_idx + 1])
    p = parse_smt_row(decoded[0])
    fl = [safe_f(v) for v in normalized_floats(p)]

    ops = []
    for year in years:
        semi_doy = max(1, int(round(fl[0])))
        prepa_doy = max(1, int(round(semi_doy + fl[1]))) if p['has_prepa'] else None
        ferti_dates = ordered_fertilisation_dates(p, fl)

        next_entry_doy = prepa_doy if prepa_doy is not None else semi_doy
        latest_rec_doy = days_in_year(year) + next_entry_doy - HARVEST_BUFFER_DAYS
        max_last_op_doy = latest_rec_doy - MIN_DAYS_LAST_OP_TO_HARVEST

        ferti_events = []
        if ferti_dates['f1'] is not None:
            ferti_events.append((ferti_dates['f1'], p['nb_f1'], p['f1_t1'], fl[6], p['f1_t2'], fl[7]))
        if ferti_dates['f2'] is not None:
            ferti_events.append((ferti_dates['f2'], p['nb_f2'], p['f2_t1'], fl[8], p['f2_t2'], fl[9]))
        if ferti_dates['f3'] is not None:
            ferti_events.append((ferti_dates['f3'], p['nb_f3'], p['f3_t1'], fl[10], p['f3_t2'], fl[11]))
        ferti_events = [event for event in ferti_events if event[0] <= max_last_op_doy]

        last_doy = ferti_events[-1][0] if ferti_events else semi_doy
        rec_doy = max(int(round(fl[5])), last_doy + MIN_DAYS_LAST_OP_TO_HARVEST)
        rec_doy = min(rec_doy, latest_rec_doy)
        if rec_doy <= last_doy:
            raise ValueError(
                f'Calendrier impossible pour {parcelle_id} campagne {year}: '
                f'dernière opération DOY {last_doy}, récolte max DOY {latest_rec_doy}'
            )

        base = {'Trait': parcelle_id, 'nom_MAELIA': f'P1_{year}',
                'plant_sem': CROP, 'annee_deb': year}

        if p['has_prepa']:
            ops.append({**base, 'id_operation': 'PREPA', 'ordre_op': '',
                        'DATE': doy_to_date_str(year, prepa_doy),
                        'PROF': PREPA_DEPTHS.get(p['prepa_t1'], ''), 'TYPE': p['prepa_t1'], 'DOSE': ''})
            if p['nb_prepa'] == 2:
                ops.append({**base, 'id_operation': 'PREPA', 'ordre_op': '2',
                            'DATE': doy_to_date_str(year, prepa_doy),
                            'PROF': PREPA_DEPTHS.get(p['prepa_t2'], ''), 'TYPE': p['prepa_t2'], 'DOSE': ''})

        ops.append({**base, 'id_operation': 'SEMIS', 'ordre_op': '',
                    'DATE': doy_to_date_str(year, semi_doy),
                    'PROF': '', 'TYPE': '', 'DOSE': ''})

        for ordre, (doy, nb, t1, d1, t2, d2) in enumerate(ferti_events, 1):
            ds = doy_to_date_str(year, doy)
            ops.append({**base, 'id_operation': 'FERTI_Min', 'ordre_op': str(ordre),
                        'DATE': ds, 'PROF': '', 'TYPE': t1, 'DOSE': str(round(d1, 1))})
            if nb == 2:
                ops.append({**base, 'id_operation': 'FERTI_Min', 'ordre_op': str(ordre),
                            'DATE': ds, 'PROF': '', 'TYPE': t2, 'DOSE': str(round(d2, 1))})

        ops.append({**base, 'id_operation': 'RECOLTE', 'ordre_op': '',
                    'DATE': doy_to_date_str(year, rec_doy),
                    'PROF': '', 'TYPE': '', 'DOSE': ''})
    return ops

# ─── Générer tous les fichiers dateDose ───────────────────────────────────────
print(f'Génération de {N_SIMU} fichiers dateDose distribués...')
for i in range(N_SIMU):
    path = VARIANTS_DIR / f'dateDose_smt_{i:03d}.csv'
    all_ops = []
    for j, parcelle_id in enumerate(ALL_PARCELLES):
        point_idx = i * len(ALL_PARCELLES) + j
        all_ops.extend(generate_ops_for_parcelle(point_idx, parcelle_id, ANNEES_DOSE))

    issues = validate_datedose_rows(all_ops)
    if issues:
        preview = '\n  - '.join(issues[:10])
        raise ValueError(f'Calendrier dateDose invalide pour simulation {i:03d}:\n  - {preview}')

    df = pd.DataFrame(all_ops, columns=COLS)
    df.to_csv(path, sep=';', index=False)
    if i % 10 == 0 or i == N_SIMU - 1:
        print(f'  Simulation {i:03d} : {len(df)} opérations ({len(ALL_PARCELLES)} parcelles traitées)')

# Contrôle anti-régression : si les dates ont été converties depuis le 1er janvier
# au lieu du 1er août, MAELIA démarre après les semis et les logs restent vides.
_check = pd.read_csv(VARIANTS_DIR / 'dateDose_smt_000.csv', sep=';')
_check_semis = pd.to_datetime(
    _check.loc[_check['id_operation'] == 'SEMIS', 'DATE'],
    dayfirst=True,
    errors='coerce',
)
_check_campaign = pd.to_datetime(
    _check.loc[_check['id_operation'] == 'SEMIS', 'annee_deb'].astype(int).astype(str) + '-08-01',
    errors='coerce',
)
if (_check_semis.reset_index(drop=True) < _check_campaign.reset_index(drop=True)).any():
    _bad = _check.loc[_check['id_operation'] == 'SEMIS'].head(5)
    raise ValueError(
        'Dates de semis invalides: au moins un semis est avant le 1er août de sa campagne. '
        'Recharge le notebook depuis le fichier modifié, puis relance les cellules de définition du plan et de génération dateDose.\n'
        + _bad.to_string(index=False)
    )

print(f'\nFichiers écrits dans : {VARIANTS_DIR}')
# Out:
# Génération de 100 fichiers dateDose distribués...
#   Simulation 000 : 24 opérations (1 parcelles traitées)
#   Simulation 010 : 60 opérations (1 parcelles traitées)
#   Simulation 020 : 36 opérations (1 parcelles traitées)
#   Simulation 030 : 60 opérations (1 parcelles traitées)
#   Simulation 040 : 24 opérations (1 parcelles traitées)
#   Simulation 050 : 36 opérations (1 parcelles traitées)
#   Simulation 060 : 24 opérations (1 parcelles traitées)
#   Simulation 070 : 72 opérations (1 parcelles traitées)
#   Simulation 080 : 108 opérations (1 parcelles traitées)
#   Simulation 090 : 84 opérations (1 parcelles traitées)
#   Simulation 099 : 72 opérations (1 parcelles traitées)
#
# Fichiers écrits dans : /Users/benjamin/Workspace_GAMA/MAELIA/includes/terrainTest/modeleAgricole/agriculteurs/variants_SMT

# %%
df.head(20)
# Out:
#          Trait nom_MAELIA plant_sem  annee_deb id_operation ordre_op  \
# 0   beauce_5_1    P1_2019       ble       2019        PREPA
# 1   beauce_5_1    P1_2019       ble       2019        SEMIS
# 2   beauce_5_1    P1_2019       ble       2019    FERTI_Min        1
# 3   beauce_5_1    P1_2019       ble       2019    FERTI_Min        2
# 4   beauce_5_1    P1_2019       ble       2019    FERTI_Min        3
# 5   beauce_5_1    P1_2019       ble       2019      RECOLTE
# 6   beauce_5_1    P1_2020       ble       2020        PREPA
# 7   beauce_5_1    P1_2020       ble       2020        SEMIS
# 8   beauce_5_1    P1_2020       ble       2020    FERTI_Min        1
# 9   beauce_5_1    P1_2020       ble       2020    FERTI_Min        2
# 10  beauce_5_1    P1_2020       ble       2020    FERTI_Min        3
# 11  beauce_5_1    P1_2020       ble       2020      RECOLTE
# 12  beauce_5_1    P1_2021       ble       2021        PREPA
# 13  beauce_5_1    P1_2021       ble       2021        SEMIS
# 14  beauce_5_1    P1_2021       ble       2021    FERTI_Min        1
# 15  beauce_5_1    P1_2021       ble       2021    FERTI_Min        2
# 16  beauce_5_1    P1_2021       ble       2021    FERTI_Min        3
# 17  beauce_5_1    P1_2021       ble       2021      RECOLTE
# 18  beauce_5_1    P1_2022       ble       2022        PREPA
# 19  beauce_5_1    P1_2022       ble       2022        SEMIS
#
#           DATE PROF                       TYPE  DOSE
# 0   07/02/2019       Preparationdulitdesemence
# 1   13/03/2019
# 2   05/07/2019                              AN  15.2
# 3   17/11/2019                              AN  64.4
# 4   18/11/2019                         mineral  78.8
# 5   25/11/2019
# 6   07/02/2020       Preparationdulitdesemence
# 7   12/03/2020
# 8   04/07/2020                              AN  15.2
# 9   16/11/2020                              AN  64.4
# 10  17/11/2020                         mineral  78.8
# 11  24/11/2020
# 12  07/02/2021       Preparationdulitdesemence
# 13  13/03/2021
# 14  05/07/2021                              AN  15.2
# 15  17/11/2021                              AN  64.4
# 16  18/11/2021                         mineral  78.8
# 17  25/11/2021
# 18  07/02/2022       Preparationdulitdesemence
# 19  13/03/2022

# %% [markdown]
# ## 4. Lancement des simulations GAMA (headless)
#
# Chaque simulation :
# 1. Génère un fichier XML de plan d'expérience GAMA.
# 2. Lance `gama-headless.sh` avec ce XML.
# 3. Écrit les logs dans `/tmp/gama_smt.log` sans les streamer dans la cellule.
#
# > Pour suivre les logs depuis un terminal : `tail -f /tmp/gama_smt.log`

# %%
# ─── Générateur XML headless ──────────────────────────────────────────────────

def make_xml(nom_simu, datedose_path):
    """Génère le contenu XML du plan d'expérience GAMA headless."""
    root = ET.Element('Experiment_plan')
    sim  = ET.SubElement(root, 'Simulation')
    sim.set('experiment',  'simulationBase')
    sim.set('finalStep',   str(FINAL_STEP))
    sim.set('id',          '0')
    sim.set('seed',        '1.0')
    sim.set('sourcePath',  str(MODEL_PATH))

    params = ET.SubElement(sim, 'Parameters')

    def p(name, ptype, value, var):
        el = ET.SubElement(params, 'Parameter')
        el.set('name', name)
        el.set('type', ptype)
        el.set('value', str(value))
        el.set('var', var)

    p('executerSurCluster: ',                  'BOOLEAN', 'false',                               'executerSurCluster')
    p('cheminRacineMaelia',                    'STRING',  CHEMIN_RACINE,                         'cheminRacineMaelia')
    p('cheminModeleVersDonnees',               'STRING',  str(MAELIA_ROOT / 'includes') + '/',   'cheminModeleVersDonnees')
    p('cheminSorties',                         'STRING',  str(LOG_DIR),                          'cheminRelatifDuDossierDeSortieDeSimulation')
    p('anneeDebutSimulation : ',               'INT',     ANNEE_DEBUT,                           'anneeDebutSimulation')
    p('nbAnneesSimulation : ',                 'INT',     NB_ANNEES,                             'nbAnneesSimulation')
    p('nomSimulation : ',                      'STRING',  nom_simu,                              'nomSimulation')
    p('nomDecoupageZonePourLectureFichiers : ', 'STRING',  NOM_DECOUPAGE,                         'nomDecoupageZonePourLectureFichiers')
    p('simulationSurParcelle : ',              'BOOLEAN', 'true',                                'executerUneSeuleParcelle')
    p('idParcelleASimuler : ',                 'STRING',  'beauce_5_1',                          'nomParcelleAffichee')
    p('executerModeleAgricole : ',             'BOOLEAN', 'true',                                'executerModeleAgricole')
    p('nomChoixAssolement : ',                 'STRING',  'DateDose',                            'nomChoixAssolement')
    p('fichierDateDose : ',                    'STRING',  str(datedose_path),                    'fichierDateDose')
    p('avecContrainteDeMainOeuvre : ',         'BOOLEAN', 'false',                               'avecContrainteDeMainOeuvre')
    p('isIrrigationSimulee : ',                'BOOLEAN', 'false',                               'isIrrigationSimulee')
    p('executerModeleHydrographique : ',       'BOOLEAN', 'false',                               'executerModeleHydrographique')
    p('executerModeleNormatif : ',             'BOOLEAN', 'false',                               'executerModeleNormatif')
    p('executerEcritureFichiers : ',           'BOOLEAN', 'true',                                'executerEcritureFichiers')
    p('sorties eau',                           'BOOLEAN', 'true',                                'sorties_eau')
    p('sorties azote',                         'BOOLEAN', 'true',                                'sorties_azote')
    p('sorties carbone et GES',                'BOOLEAN', 'true',                                'sorties_carboneGES')
    p('Sortie N_Cstock_Parcelles',             'BOOLEAN', 'true',                                'N_Cstock_Parcelles')
    p('Sortie N_lixi_Parcelles',               'BOOLEAN', 'true',                                'N_lixi_Parcelles')
    # Note: 'suiviOTParParcelle' est déjà true par défaut dans launcherBase.gaml.
    # Son label GAML contient des accents ('Suivi détaillé…') qui ne peuvent pas
    # être encodés sans risque dans le XML headless → paramètre omis volontairement.

    ET.SubElement(sim, 'Outputs')

    try:
        ET.indent(root, space='  ')
    except AttributeError:
        pass  # Python < 3.9

    buf = io.BytesIO()
    ET.ElementTree(root).write(buf, encoding='UTF-8', xml_declaration=True)
    xml_str = buf.getvalue().decode('UTF-8')
    # Normaliser la déclaration XML (double quotes)
    xml_str = xml_str.replace("<?xml version='1.0' encoding='UTF-8'?>",
                              '<?xml version="1.0" encoding="UTF-8" standalone="no"?>')
    return xml_str


# ─── Fonction de lancement + écriture des logs ───────────────────────────────

def find_output_dir(nom_simu, ts_before):
    """Trouve le répertoire de sortie MAELIA créé après ts_before."""
    expected_prefix = f'{NOM_DECOUPAGE}_{nom_simu}_'
    for _ in range(20):
        matches = [
            p for p in LOG_DIR.glob(f'{NOM_DECOUPAGE}_*')
            if p.is_dir()
            and p.stat().st_mtime >= ts_before
            and (p.name.startswith(expected_prefix) or nom_simu in p.name)
        ]
        if matches:
            return sorted(matches, key=lambda p: p.stat().st_mtime)[-1]
        time.sleep(1)
    return None


def run_simulation(nom_simu, xml_path, gama_ws):
    """
    Lance une simulation GAMA headless.
    Écrit stdout/stderr dans GAMA_LOG sans streamer dans la cellule notebook.
    Retourne (code_retour, out_dir | None).
    """
    gama_ws.mkdir(parents=True, exist_ok=True)
    cmd = ['bash', GAMA_HEADLESS, str(xml_path), str(gama_ws)]
    t0  = time.time()
    ts_before = t0 - 0.5

    print(f'\n{nom_simu} lancé. Logs terminal : tail -f {GAMA_LOG}', flush=True)

    with open(GAMA_LOG, 'a') as flog:
        flog.write(f'\n{"=" * 62}\n[{nom_simu}] {time.strftime("%H:%M:%S")}\n')
        flog.write(f'Commande: {" ".join(cmd)}\n{"=" * 62}\n')
        proc = subprocess.run(
            cmd,
            stdout=flog,
            stderr=subprocess.STDOUT,
            text=True,
        )

    elapsed  = time.time() - t0
    ok       = (proc.returncode == 0)
    out_dir  = find_output_dir(nom_simu, ts_before) if ok else None
    status   = 'OK' if ok else f'ERREUR (code {proc.returncode})'

    print(f'  [{status}] {nom_simu} terminé en {elapsed:.1f}s', flush=True)
    if out_dir:
        print(f'  Sorties : {out_dir.name}', flush=True)
    else:
        print(f'  Sorties : non trouvées sous {LOG_DIR}', flush=True)
    return proc.returncode, out_dir

# %%
# ─── Boucle principale ────────────────────────────────────────────────────────

# Vider le fichier de log
GAMA_LOG.write_text('')
print(f'Log GAMA → {GAMA_LOG}')
print('Pour suivre en temps réel dans un terminal :')
print(f'  tail -f {GAMA_LOG}')
print()

results = {}    # nom_simu → Path | None
t_global = time.time()

for i in range(N_DOE):
    nom_simu  = f'smt_{i:03d}'
    csv_path  = VARIANTS_DIR / f'dateDose_{nom_simu}.csv'
    xml_path  = XML_DIR / f'{nom_simu}.xml'
    gama_ws   = XML_DIR / f'ws_{nom_simu}'

    # Écrire le XML
    xml_path.write_text(make_xml(nom_simu, csv_path))

    # Lancer la simulation
    ret, out_dir = run_simulation(nom_simu, xml_path, gama_ws)
    results[nom_simu] = out_dir

n_ok    = sum(1 for v in results.values() if v is not None)
elapsed = time.time() - t_global
print(f'\n{"═" * 62}')
print(f'  Terminé : {n_ok}/{N_DOE} simulations OK  ({elapsed:.0f}s total)')
print(f'{"═" * 62}')
# Out:
# Log GAMA → /tmp/gama_smt.log
# Pour suivre en temps réel dans un terminal :
#   tail -f /tmp/gama_smt.log
#
#
# smt_000 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_000 terminé en 16.7s
#   Sorties : terrainTest_smt_000_2026-06-02_10_42_37
#
# smt_001 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_001 terminé en 16.6s
#   Sorties : terrainTest_smt_001_2026-06-02_10_42_53
#
# smt_002 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_002 terminé en 13.4s
#   Sorties : terrainTest_smt_002_2026-06-02_10_43_07
#
# smt_003 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_003 terminé en 14.0s
#   Sorties : terrainTest_smt_003_2026-06-02_10_43_21
#
# smt_004 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_004 terminé en 15.6s
#   Sorties : terrainTest_smt_004_2026-06-02_10_43_36
#
# smt_005 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_005 terminé en 13.8s
#   Sorties : terrainTest_smt_005_2026-06-02_10_43_50
#
# smt_006 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_006 terminé en 13.4s
#   Sorties : terrainTest_smt_006_2026-06-02_10_44_04
#
# smt_007 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_007 terminé en 13.7s
#   Sorties : terrainTest_smt_007_2026-06-02_10_44_17
#
# smt_008 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_008 terminé en 13.5s
#   Sorties : terrainTest_smt_008_2026-06-02_10_44_31
#
# smt_009 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_009 terminé en 13.5s
#   Sorties : terrainTest_smt_009_2026-06-02_10_44_44
#
# smt_010 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_010 terminé en 13.2s
#   Sorties : terrainTest_smt_010_2026-06-02_10_44_58
#
# smt_011 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_011 terminé en 16.6s
#   Sorties : terrainTest_smt_011_2026-06-02_10_45_14
#
# smt_012 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_012 terminé en 14.5s
#   Sorties : terrainTest_smt_012_2026-06-02_10_45_28
#
# smt_013 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_013 terminé en 13.5s
#   Sorties : terrainTest_smt_013_2026-06-02_10_45_42
#
# smt_014 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_014 terminé en 14.0s
#   Sorties : terrainTest_smt_014_2026-06-02_10_45_56
#
# smt_015 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_015 terminé en 13.7s
#   Sorties : terrainTest_smt_015_2026-06-02_10_46_10
#
# smt_016 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_016 terminé en 16.1s
#   Sorties : terrainTest_smt_016_2026-06-02_10_46_26
#
# smt_017 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_017 terminé en 13.6s
#   Sorties : terrainTest_smt_017_2026-06-02_10_46_40
#
# smt_018 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_018 terminé en 13.8s
#   Sorties : terrainTest_smt_018_2026-06-02_10_46_53
#
# smt_019 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_019 terminé en 13.6s
#   Sorties : terrainTest_smt_019_2026-06-02_10_47_07
#
# smt_020 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_020 terminé en 13.8s
#   Sorties : terrainTest_smt_020_2026-06-02_10_47_21
#
# smt_021 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_021 terminé en 13.9s
#   Sorties : terrainTest_smt_021_2026-06-02_10_47_35
#
# smt_022 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_022 terminé en 13.7s
#   Sorties : terrainTest_smt_022_2026-06-02_10_47_48
#
# smt_023 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_023 terminé en 14.9s
#   Sorties : terrainTest_smt_023_2026-06-02_10_48_02
#
# smt_024 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_024 terminé en 16.3s
#   Sorties : terrainTest_smt_024_2026-06-02_10_48_19
#
# smt_025 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_025 terminé en 13.6s
#   Sorties : terrainTest_smt_025_2026-06-02_10_48_33
#
# smt_026 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_026 terminé en 13.8s
#   Sorties : terrainTest_smt_026_2026-06-02_10_48_47
#
# smt_027 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_027 terminé en 13.6s
#   Sorties : terrainTest_smt_027_2026-06-02_10_49_00
#
# smt_028 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_028 terminé en 14.1s
#   Sorties : terrainTest_smt_028_2026-06-02_10_49_15
#
# smt_029 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_029 terminé en 13.5s
#   Sorties : terrainTest_smt_029_2026-06-02_10_49_28
#
# smt_030 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_030 terminé en 14.4s
#   Sorties : terrainTest_smt_030_2026-06-02_10_49_42
#
# smt_031 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_031 terminé en 13.4s
#   Sorties : terrainTest_smt_031_2026-06-02_10_49_56
#
# smt_032 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_032 terminé en 14.1s
#   Sorties : terrainTest_smt_032_2026-06-02_10_50_10
#
# smt_033 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_033 terminé en 13.7s
#   Sorties : terrainTest_smt_033_2026-06-02_10_50_24
#
# smt_034 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_034 terminé en 13.7s
#   Sorties : terrainTest_smt_034_2026-06-02_10_50_38
#
# smt_035 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_035 terminé en 13.8s
#   Sorties : terrainTest_smt_035_2026-06-02_10_50_51
#
# smt_036 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_036 terminé en 14.6s
#   Sorties : terrainTest_smt_036_2026-06-02_10_51_05
#
# smt_037 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_037 terminé en 14.3s
#   Sorties : terrainTest_smt_037_2026-06-02_10_51_20
#
# smt_038 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_038 terminé en 14.6s
#   Sorties : terrainTest_smt_038_2026-06-02_10_51_35
#
# smt_039 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_039 terminé en 15.1s
#   Sorties : terrainTest_smt_039_2026-06-02_10_51_50
#
# smt_040 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_040 terminé en 14.3s
#   Sorties : terrainTest_smt_040_2026-06-02_10_52_04
#
# smt_041 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_041 terminé en 13.7s
#   Sorties : terrainTest_smt_041_2026-06-02_10_52_18
#
# smt_042 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_042 terminé en 14.3s
#   Sorties : terrainTest_smt_042_2026-06-02_10_52_32
#
# smt_043 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_043 terminé en 14.2s
#   Sorties : terrainTest_smt_043_2026-06-02_10_52_46
#
# smt_044 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_044 terminé en 14.0s
#   Sorties : terrainTest_smt_044_2026-06-02_10_53_01
#
# smt_045 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_045 terminé en 13.6s
#   Sorties : terrainTest_smt_045_2026-06-02_10_53_14
#
# smt_046 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_046 terminé en 14.6s
#   Sorties : terrainTest_smt_046_2026-06-02_10_53_29
#
# smt_047 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_047 terminé en 13.6s
#   Sorties : terrainTest_smt_047_2026-06-02_10_53_42
#
# smt_048 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_048 terminé en 13.4s
#   Sorties : terrainTest_smt_048_2026-06-02_10_53_56
#
# smt_049 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_049 terminé en 13.5s
#   Sorties : terrainTest_smt_049_2026-06-02_10_54_09
#
# smt_050 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_050 terminé en 13.7s
#   Sorties : terrainTest_smt_050_2026-06-02_10_54_23
#
# smt_051 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_051 terminé en 15.2s
#   Sorties : terrainTest_smt_051_2026-06-02_10_54_38
#
# smt_052 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_052 terminé en 13.9s
#   Sorties : terrainTest_smt_052_2026-06-02_10_54_52
#
# smt_053 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_053 terminé en 13.8s
#   Sorties : terrainTest_smt_053_2026-06-02_10_55_06
#
# smt_054 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_054 terminé en 12.9s
#   Sorties : terrainTest_smt_054_2026-06-02_10_55_19
#
# smt_055 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_055 terminé en 13.9s
#   Sorties : terrainTest_smt_055_2026-06-02_10_55_33
#
# smt_056 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_056 terminé en 13.3s
#   Sorties : terrainTest_smt_056_2026-06-02_10_55_46
#
# smt_057 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_057 terminé en 13.8s
#   Sorties : terrainTest_smt_057_2026-06-02_10_56_00
#
# smt_058 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_058 terminé en 12.9s
#   Sorties : terrainTest_smt_058_2026-06-02_10_56_13
#
# smt_059 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_059 terminé en 14.3s
#   Sorties : terrainTest_smt_059_2026-06-02_10_56_27
#
# smt_060 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_060 terminé en 14.1s
#   Sorties : terrainTest_smt_060_2026-06-02_10_56_41
#
# smt_061 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_061 terminé en 13.7s
#   Sorties : terrainTest_smt_061_2026-06-02_10_56_55
#
# smt_062 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_062 terminé en 13.8s
#   Sorties : terrainTest_smt_062_2026-06-02_10_57_09
#
# smt_063 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_063 terminé en 14.1s
#   Sorties : terrainTest_smt_063_2026-06-02_10_57_23
#
# smt_064 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_064 terminé en 13.7s
#   Sorties : terrainTest_smt_064_2026-06-02_10_57_37
#
# smt_065 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_065 terminé en 14.8s
#   Sorties : terrainTest_smt_065_2026-06-02_10_57_51
#
# smt_066 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_066 terminé en 15.6s
#   Sorties : terrainTest_smt_066_2026-06-02_10_58_07
#
# smt_067 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_067 terminé en 15.6s
#   Sorties : terrainTest_smt_067_2026-06-02_10_58_22
#
# smt_068 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_068 terminé en 14.0s
#   Sorties : terrainTest_smt_068_2026-06-02_10_58_37
#
# smt_069 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_069 terminé en 13.6s
#   Sorties : terrainTest_smt_069_2026-06-02_10_58_50
#
# smt_070 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_070 terminé en 13.6s
#   Sorties : terrainTest_smt_070_2026-06-02_10_59_04
#
# smt_071 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_071 terminé en 13.7s
#   Sorties : terrainTest_smt_071_2026-06-02_10_59_18
#
# smt_072 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_072 terminé en 13.7s
#   Sorties : terrainTest_smt_072_2026-06-02_10_59_31
#
# smt_073 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_073 terminé en 14.1s
#   Sorties : terrainTest_smt_073_2026-06-02_10_59_45
#
# smt_074 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_074 terminé en 14.3s
#   Sorties : terrainTest_smt_074_2026-06-02_11_00_00
#
# smt_075 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_075 terminé en 15.3s
#   Sorties : terrainTest_smt_075_2026-06-02_11_00_14
#
# smt_076 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_076 terminé en 13.4s
#   Sorties : terrainTest_smt_076_2026-06-02_11_00_28
#
# smt_077 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_077 terminé en 13.3s
#   Sorties : terrainTest_smt_077_2026-06-02_11_00_42
#
# smt_078 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_078 terminé en 13.7s
#   Sorties : terrainTest_smt_078_2026-06-02_11_00_55
#
# smt_079 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_079 terminé en 13.7s
#   Sorties : terrainTest_smt_079_2026-06-02_11_01_09
#
# smt_080 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_080 terminé en 14.9s
#   Sorties : terrainTest_smt_080_2026-06-02_11_01_24
#
# smt_081 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_081 terminé en 16.2s
#   Sorties : terrainTest_smt_081_2026-06-02_11_01_40
#
# smt_082 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_082 terminé en 15.4s
#   Sorties : terrainTest_smt_082_2026-06-02_11_01_55
#
# smt_083 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_083 terminé en 18.3s
#   Sorties : terrainTest_smt_083_2026-06-02_11_02_13
#
# smt_084 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_084 terminé en 15.9s
#   Sorties : terrainTest_smt_084_2026-06-02_11_02_29
#
# smt_085 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_085 terminé en 15.7s
#   Sorties : terrainTest_smt_085_2026-06-02_11_02_45
#
# smt_086 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_086 terminé en 14.2s
#   Sorties : terrainTest_smt_086_2026-06-02_11_03_00
#
# smt_087 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_087 terminé en 17.5s
#   Sorties : terrainTest_smt_087_2026-06-02_11_03_17
#
# smt_088 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_088 terminé en 15.0s
#   Sorties : terrainTest_smt_088_2026-06-02_11_03_32
#
# smt_089 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_089 terminé en 13.4s
#   Sorties : terrainTest_smt_089_2026-06-02_11_03_46
#
# smt_090 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_090 terminé en 13.8s
#   Sorties : terrainTest_smt_090_2026-06-02_11_03_59
#
# smt_091 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_091 terminé en 15.3s
#   Sorties : terrainTest_smt_091_2026-06-02_11_04_14
#
# smt_092 lancé. Logs terminal : tail -f /tmp/gama_smt.log
#   [OK] smt_092 terminé en 14.4s
#   Sorties : terrainTest_smt_092_2026-06-02_11_04_29
#
# smt_093 lancé. Logs terminal : tail -f /tmp/gama_smt.log
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 23
#      19     # Écrire le XML
#      20     xml_path.write_text(make_xml(nom_simu, csv_path))
#      21
#      22     # Lancer la simulation
# ---> 23     ret, out_dir = run_simulation(nom_simu, xml_path, gama_ws)
#      24     results[nom_simu] = out_dir
#      25
#      26 n_ok    = sum(1 for v in results.values() if v is not None)
#
# Cell In[6], line 99, in run_simulation(nom_simu, xml_path, gama_ws)
#      95
#      96     with open(GAMA_LOG, 'a') as flog:
#      97         flog.write(f'\n{"=" * 62}\n[{nom_simu}] {time.strftime("%H:%M:%S")}\n')
#      98         flog.write(f'Commande: {" ".join(cmd)}\n{"=" * 62}\n')
# ---> 99         proc = subprocess.run(
#     100             cmd,
#     101             stdout=flog,
#     102             stderr=subprocess.STDOUT,
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/subprocess.py:2046, in Popen._wait(self, timeout)
#    2044 if self.returncode is not None:
#    2045     break  # Another thread waited.
# -> 2046 (pid, sts) = self._try_wait(0)
#    2047 # Check the pid and loop as waitpid has been known to
#    2048 # return 0 even without WNOHANG in odd situations.
#    2049 # http://bugs.python.org/issue14396.
#    2050 if pid == self.pid:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/subprocess.py:2004, in Popen._try_wait(self, wait_flags)
#    2002 """All callers to this function MUST hold self._waitpid_lock."""
#    2003 try:
# -> 2004     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2005 except ChildProcessError:
#    2006     # This happens if SIGCLD is set to be ignored or waiting
#    2007     # for child processes has otherwise been disabled for our
#    2008     # process.  This child is dead, we can't get the status.
#    2009     pid = self.pid
#
# KeyboardInterrupt:

# %%
# ─── Reconstruction des résultats depuis le répertoire de logs ────────────────
# Exécuter cette cellule si les simulations ont déjà tourné mais que `results`
# n'est plus en mémoire (kernel redémarré, interruption, etc.).

def _output_dir_has_expected_files(path):
    return (
        (path / 'sorties_CN.csv').exists()
        or (path / 'suiviOTParParcelle.csv').exists()
        or (path / 'suiviOTParParcelle_journalier.csv').exists()
    )

def _batch_start_cutoff():
    times = []
    for i in range(N_DOE):
        console = XML_DIR / f'ws_smt_{i:03d}' / 'console-outputs-0.txt'
        if console.exists():
            times.append(console.stat().st_mtime)
    return min(times) - 120 if times else 0

def rebuild_results_from_logs():
    latest = {}
    unmatched = []
    cutoff = _batch_start_cutoff()

    for d in LOG_DIR.glob(f'{NOM_DECOUPAGE}_*'):
        if not d.is_dir() or not _output_dir_has_expected_files(d):
            continue
        if 'smoke_patch' in d.name or d.stat().st_mtime < cutoff:
            continue

        matched = False
        for i in range(N_DOE):
            nom_simu = f'smt_{i:03d}'
            if f'_{nom_simu}_' in d.name or d.name.startswith(f'{NOM_DECOUPAGE}_{nom_simu}_'):
                if nom_simu not in latest or d.stat().st_mtime > latest[nom_simu].stat().st_mtime:
                    latest[nom_simu] = d
                matched = True
                break

        if not matched:
            unmatched.append(d)

    # Compatibility with logs produced before the launcher fix, when all folders
    # could be named terrainTest_beauce_5_* instead of terrainTest_smt_XXX_*.
    missing = [f'smt_{i:03d}' for i in range(N_DOE) if f'smt_{i:03d}' not in latest]
    for nom_simu, d in zip(missing, sorted(unmatched, key=lambda p: p.stat().st_mtime)):
        latest[nom_simu] = d

    return {k: v for k, v in sorted(latest.items())}

results = rebuild_results_from_logs()

n_found = len(results)
print(f'Dossiers trouvés : {n_found}/{N_DOE}')
for nom, d in list(results.items())[:10]:
    print(f'  {nom} → {d.name}')
if n_found > 10:
    print(f'  … ({n_found - 10} autres)')
if n_found == 0:
    print(f'Aucun dossier exploitable trouvé sous {LOG_DIR}')
# Out:
# Dossiers trouvés : 34/100
#   smt_000 → terrainTest_beauce_5_2026-05-11_14_38_09
#   smt_001 → terrainTest_beauce_5_2026-05-11_14_38_59
#   smt_002 → terrainTest_beauce_5_2026-05-11_14_39_53
#   smt_003 → terrainTest_beauce_5_2026-05-11_14_40_57
#   smt_004 → terrainTest_beauce_5_2026-05-11_14_42_02
#   smt_005 → terrainTest_beauce_5_2026-05-11_14_43_11
#   smt_006 → terrainTest_beauce_5_2026-05-11_14_44_19
#   smt_007 → terrainTest_beauce_5_2026-05-11_14_45_31
#   smt_008 → terrainTest_beauce_5_2026-05-11_14_46_31
#   smt_009 → terrainTest_beauce_5_2026-05-11_14_47_35
#   … (24 autres)

# %% [markdown]
# ## 5. Collecte des résultats

# %%
# ─── Diagnostic post-run ─────────────────────────────────────────────────────
print('═' * 62)
print('DIAGNOSTIC')
print('═' * 62)

for i in range(N_DOE):
    nom_simu = f'smt_{i:03d}'
    gama_ws  = XML_DIR / f'ws_{nom_simu}'
    out_dir  = results.get(nom_simu)

    print(f'\n── {nom_simu} ──')

    # 1. Code retour GAMA
    console = gama_ws / 'console-outputs-0.txt'
    if console.exists():
        lines = console.read_text(errors='replace').splitlines()
        # Dernières lignes utiles (filtrer le bruit)
        tail = [l for l in lines if l.strip() and not l.startswith('Adding unit')][-10:]
        print('  console (10 dernières lignes utiles) :')
        for l in tail:
            print(f'    {l}')
    else:
        print(f'  console-outputs-0.txt introuvable dans {gama_ws}')

    # 2. Dossier de sortie MAELIA trouvé ?
    if out_dir:
        print(f'  → dossier sortie : {out_dir}')
        csvs = list(out_dir.glob('*.csv'))
        print(f'  → fichiers CSV   : {[c.name for c in csvs]}')
    else:
        print(f'  → aucun dossier sortie trouvé sous {LOG_DIR}')
        # Cherche quand même des dossiers récents pour aider au diagnostic
        all_dirs = sorted(LOG_DIR.glob(f'{NOM_DECOUPAGE}_*'), key=lambda p: p.stat().st_mtime, reverse=True)
        if all_dirs:
            print(f'  → dossiers existants les plus récents dans log/ :')
            for d in all_dirs[:5]:
                print(f'      {d.name}')
        else:
            print(f'  → log/ est vide ou n\'existe pas')
# Out:
# ══════════════════════════════════════════════════════════════
# DIAGNOSTIC
# ══════════════════════════════════════════════════════════════
#
# ── smt_000 ──
#   console (10 dernières lignes utiles) :
#     1_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=0ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 15840ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_38_09
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_001 ──
#   console (10 dernières lignes utiles) :
#     1_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 19419ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_38_59
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_002 ──
#   console (10 dernières lignes utiles) :
#     1_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=0ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 16492ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_39_53
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_003 ──
#   console (10 dernières lignes utiles) :
#     1_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=0ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 15713ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_40_57
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_004 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 15211ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_42_02
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_005 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=0ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 14979ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_43_11
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_006 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 16661ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_44_19
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_007 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 13771ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_45_31
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_008 ──
#   console (10 dernières lignes utiles) :
#     2_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=2ms
#     [LayeredDisplayOutput.update] END for map total=2ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 13636ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_46_31
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_009 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 13651ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_47_35
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_010 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=43ms
#     [LayeredDisplayOutput.update] END for Meteo total=43ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 12353ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_48_37
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_011 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 14680ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_49_36
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_012 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 13519ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_50_40
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_013 ──
#   console (10 dernières lignes utiles) :
#     2_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=2ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 14606ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_51_47
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_014 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=3ms
#     [LayeredDisplayOutput.update] END for map total=4ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 13424ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_52_53
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_015 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=0ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 12680ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_53_58
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_016 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for map total=1ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 11699ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_54_58
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_017 ──
#   console (10 dernières lignes utiles) :
#     2_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=0ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 12914ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_56_01
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_018 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 12836ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_57_05
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_019 ──
#   console (10 dernières lignes utiles) :
#     4_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for map total=1ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 14393ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_58_09
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_020 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=15ms
#     [LayeredDisplayOutput.update] END for map total=16ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 13307ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_14_59_13
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_021 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for map total=1ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 14430ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_00_16
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_022 ──
#   console (10 dernières lignes utiles) :
#     4_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 13351ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_01_20
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_023 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for map total=1ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 13230ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_02_27
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_024 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=0ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 12776ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_03_30
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_025 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=2ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for map total=1ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 11960ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_04_33
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_026 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=0ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 11669ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_05_38
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_027 ──
#   console (10 dernières lignes utiles) :
#     2_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 14462ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_06_36
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_028 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 10165ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_07_36
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_029 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=0ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 14064ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_08_30
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_030 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 11507ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_09_29
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_031 ──
#   console (10 dernières lignes utiles) :
#     3_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 10858ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_10_24
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_032 ──
#   console (10 dernières lignes utiles) :
#     2_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=1ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=0ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 12303ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_11_18
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_033 ──
#   console (10 dernières lignes utiles) :
#     2_sINIT
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for Meteo thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for Meteo total=1ms
#     Image Display Surface created for simulation Simulation 0
#     [LayeredDisplayOutput.update] START for map thread=pool-1-thread-1
#     [LayeredDisplayOutput.update] after getData().update=0ms
#     [LayeredDisplayOutput.update] END for map total=1ms
#     ....................................................................................................> GAMA  : Simulation running                            for: _________ 9998ms
#   → dossier sortie : /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log/terrainTest_beauce_5_2026-05-11_15_12_16
#   → fichiers CSV   : ['sorties_CN.csv', 'suiviOTParParcelle_journalier.csv', 'corresponsanceIlotZoneMeteo.csv', 'sorties_eau.csv', 'suivi_ajout_pools_residus.csv', 'suiviOTParParcelle.csv', 'sorties_GES.csv', 'surfaceParcelles.csv']
#
# ── smt_034 ──
#   console (10 dernières lignes utiles) :
#     /Users/benjamin/Workspace_GAMA/MAELIA/models/main/launcherBase.gaml model is being compiled...
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_035 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_035
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_036 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_036
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_037 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_037
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_038 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_038
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_039 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_039
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_040 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_040
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_041 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_041
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_042 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_042
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_043 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_043
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_044 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_044
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_045 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_045
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_046 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_046
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_047 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_047
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_048 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_048
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_049 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_049
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_050 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_050
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_051 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_051
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_052 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_052
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_053 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_053
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_054 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_054
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_055 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_055
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
# ...
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_066 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_066
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_067 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_067
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_068 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_068
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_069 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_069
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_070 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_070
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_071 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_071
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_072 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_072
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_073 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_073
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_074 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_074
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_075 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_075
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_076 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_076
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_077 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_077
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_078 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_078
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_079 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_079
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_080 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_080
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_081 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_081
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_082 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_082
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_083 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_083
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_084 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_084
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_085 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_085
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_086 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_086
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_087 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_087
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_088 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_088
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_089 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_089
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_090 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_090
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_091 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_091
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_092 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_092
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_093 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_093
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_094 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_094
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_095 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_095
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_096 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_096
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_097 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_097
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_098 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_098
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29
#
# ── smt_099 ──
#   console-outputs-0.txt introuvable dans /tmp/maelia_smt_xml/ws_smt_099
#   → aucun dossier sortie trouvé sous /Users/benjamin/Workspace_GAMA/MAELIA/models/main/log
#   → dossiers existants les plus récents dans log/ :
#       terrainTest_smoke_patch_2026-05-11_15_52_31
#       terrainTest_beauce_5_2026-05-11_15_12_16
#       terrainTest_beauce_5_2026-05-11_15_11_18
#       terrainTest_beauce_5_2026-05-11_15_10_24
#       terrainTest_beauce_5_2026-05-11_15_09_29

# %%
import struct as _struct, glob as _glob

# --- Lecture DBF ilots (une seule fois) ---
def _read_dbf_ilot_sol(dbf_path):
    """Renvoie {ilot_name: ID_SOL} depuis le shapefile ilots.dbf."""
    with open(dbf_path, 'rb') as _f:
        _d = _f.read()
    _n   = _struct.unpack('<I', _d[4:8])[0]
    _hs  = _struct.unpack('<H', _d[8:10])[0]
    _rs  = _struct.unpack('<H', _d[10:12])[0]
    _flds = []
    _off = 32
    while _d[_off] != 0x0D:
        _name = _d[_off:_off+11].split(b'\x00')[0].decode('latin1')
        _flds.append((_name, _d[_off+16]))
        _off += 32
    _off = _hs
    _out = {}
    for _ in range(_n):
        if _d[_off] == 0x2A:
            _off += _rs
            continue
        _off += 1
        _row = {}
        for _nm, _ln in _flds:
            _row[_nm] = _d[_off:_off+_ln].decode('latin1').strip()
            _off += _ln
        _out[_row['ID_ILOT']] = _row['ID_SOL']
    return _out

_DBF_PATH = (Path('/Users/benjamin/Workspace_GAMA/MAELIA/includes/terrainTest')
             / 'modeleAgricole/ilots/dansZone/ilots.dbf')
_ILOT_SOL = _read_dbf_ilot_sol(_DBF_PATH)   # {ilot_name -> sol_type}


def _read_corr_ilot_meteo(out_dir):
    """Renvoie {ilot_name: zone_meteo_int} depuis corresponsanceIlotZoneMeteo.csv."""
    _p = out_dir / 'corresponsanceIlotZoneMeteo.csv'
    if not _p.exists():
        return {}
    _df = pd.read_csv(_p, sep=';')
    return dict(zip(_df['ilot'], _df['zoneMeteo'].astype(int)))


SOL_TYPES   = ['18960_27491', '330104_330367_1', '330151_330489_1']  # A, B, C
METEO_CODES = [4756, 13218, 13761]  # sudouest, beauce, oceanique


def _zone(parcelle):
    for z in ('beauce', 'oceanique', 'sudouest'):
        if z in parcelle:
            return z
    return 'autre'


def read_simulation_outputs(out_dir):
    """
    Retourne un DataFrame long (parcelle x annee) avec les 3 sorties cibles.
    Colonnes : annee, parcelle, N_lixi, dCorg, rdt, zone, sol_type, zone_meteo
    """
    f_cn = out_dir / 'sorties_CN.csv'
    if not f_cn.exists():
        return pd.DataFrame()
    df = pd.read_csv(f_cn, sep=';',
                     usecols=['annee', 'parcelle', 'couvert',
                              'N_lixivie[kgN/ha]', 'delta_Corg[kgC/ha]'])
    df = df[df['couvert'].notna() & (df['couvert'] != 'solnu')].drop(columns='couvert')
    df = df.rename(columns={'N_lixivie[kgN/ha]': 'N_lixi',
                             'delta_Corg[kgC/ha]': 'dCorg'})

    f_ot = out_dir / 'suiviOTParParcelle.csv'
    if f_ot.exists():
        df_ot = pd.read_csv(f_ot, sep=';',
                            usecols=['annee', 'parcelle', 'OT',
                                     'RECOLTE_rendement[t/ha]'])
        df_ot = (df_ot[df_ot['OT'] == 'RECOLTE']
                 .drop(columns='OT')
                 .rename(columns={'RECOLTE_rendement[t/ha]': 'rdt'}))
        df = df.merge(df_ot, on=['annee', 'parcelle'], how='left')

    df['zone'] = df['parcelle'].apply(_zone)

    # sol_type et zone_meteo depuis shapefile + corresponsance
    _corr = _read_corr_ilot_meteo(out_dir)
    def _sol_type(p):
        ilot = '_'.join(p.rsplit('_', 1)[:-1])
        return _ILOT_SOL.get(ilot, None)
    def _zone_meteo(p):
        ilot = '_'.join(p.rsplit('_', 1)[:-1])
        return _corr.get(ilot, None)

    df['sol_type']   = df['parcelle'].apply(_sol_type)
    df['zone_meteo'] = df['parcelle'].apply(_zone_meteo)
    return df


# --- Collecte ---
all_data     = {}
summary_rows = []

for nom_simu, out_dir in results.items():
    if not (out_dir and out_dir.exists()):
        summary_rows.append({
            'simulation': nom_simu,
            'ok': False,
            'n_parcelles': 0,
            'reason': 'répertoire de sortie absent',
        })
        continue

    df = read_simulation_outputs(out_dir)
    if df.empty:
        summary_rows.append({
            'simulation': nom_simu,
            'ok': False,
            'n_parcelles': 0,
            'reason': 'sorties_CN.csv absent ou sans couvert cultivé',
        })
        continue

    all_data[nom_simu] = df
    row = {
        'simulation': nom_simu,
        'ok': True,
        'n_parcelles': df['parcelle'].nunique(),
        'reason': '',
    }
    for m in ('N_lixi', 'dCorg', 'rdt'):
        if m in df.columns:
            row[f'{m}_mean'] = df[m].mean()
            row[f'{m}_std']  = df[m].std()
    summary_rows.append(row)

results_df = pd.DataFrame(summary_rows)

for col, default in [('simulation', ''), ('ok', False), ('n_parcelles', 0), ('reason', '')]:
    if col not in results_df.columns:
        results_df[col] = default

print(f'Resultats : {int(results_df["ok"].sum())} simulations OK')
mean_cols = [c for c in results_df.columns if c.endswith('_mean')]
display_cols = ['simulation', 'ok', 'n_parcelles'] + mean_cols
if 'reason' in results_df.columns and (results_df['reason'].astype(str) != '').any():
    display_cols.append('reason')

display(results_df[display_cols].round(3))

if not results_df['ok'].any():
    print(
        "Aucune sortie exploitable n'a été collectée. Vérifie que les dossiers de logs pointés par `results` "
        "contiennent bien `sorties_CN.csv` avec au moins un couvert cultivé différent de `solnu`."
    )

print('\nDistribution (zone, sol_type, zone_meteo) sur smt_000 :')
_s0 = all_data.get('smt_000', pd.DataFrame())
if not _s0.empty:
    _avg = _s0.groupby(['zone', 'sol_type', 'zone_meteo']).size().reset_index(name='n_parcelles')
    display(_avg)

# --- Sauvegarde detail par simulation ---
results_df.to_csv(XML_DIR / 'resultats_smt.csv', index=False)
for nom_simu, df in all_data.items():
    df.to_csv(XML_DIR / f'detail_{nom_simu}.csv', index=False)
print(f'\nFichiers sauvegardes dans {XML_DIR}/')
# Out:
# Resultats : 34 simulations OK
#    simulation    ok  n_parcelles  N_lixi_mean  dCorg_mean  rdt_mean
# 0     smt_000  True            1        2.962     -191.96      4.47
# 1     smt_001  True            1        2.962     -191.96      4.47
# 2     smt_002  True            1        2.962     -191.96      4.47
# 3     smt_003  True            1        2.962     -191.96      4.47
# 4     smt_004  True            1        2.962     -191.96      4.47
# 5     smt_005  True            1        2.962     -191.96      4.47
# 6     smt_006  True            1        2.962     -191.96      4.47
# 7     smt_007  True            1        2.962     -191.96      4.47
# 8     smt_008  True            1        2.962     -191.96      4.47
# 9     smt_009  True            1        2.962     -191.96      4.47
# 10    smt_010  True            1        2.962     -191.96      4.47
# 11    smt_011  True            1        2.962     -191.96      4.47
# 12    smt_012  True            1        2.962     -191.96      4.47
# 13    smt_013  True            1        2.962     -191.96      4.47
# 14    smt_014  True            1        2.962     -191.96      4.47
# 15    smt_015  True            1        2.962     -191.96      4.47
# 16    smt_016  True            1        2.962     -191.96      4.47
# 17    smt_017  True            1        2.962     -191.96      4.47
# 18    smt_018  True            1        2.962     -191.96      4.47
# 19    smt_019  True            1        2.962     -191.96      4.47
# 20    smt_020  True            1        2.962     -191.96      4.47
# 21    smt_021  True            1        2.962     -191.96      4.47
# 22    smt_022  True            1        2.962     -191.96      4.47
# 23    smt_023  True            1        2.962     -191.96      4.47
# 24    smt_024  True            1        2.962     -191.96      4.47
# 25    smt_025  True            1        2.962     -191.96      4.47
# 26    smt_026  True            1        2.962     -191.96      4.47
# 27    smt_027  True            1        2.962     -191.96      4.47
# 28    smt_028  True            1        2.962     -191.96      4.47
# 29    smt_029  True            1        2.962     -191.96      4.47
# 30    smt_030  True            1        2.962     -191.96      4.47
# 31    smt_031  True            1        2.962     -191.96      4.47
# 32    smt_032  True            1        2.962     -191.96      4.47
# 33    smt_033  True            1        2.962     -191.96      4.47
# Distribution (zone, sol_type, zone_meteo) sur smt_000 :
#      zone     sol_type  zone_meteo  n_parcelles
# 0  beauce  18960_27491       13218            5
# Fichiers sauvegardes dans /tmp/maelia_smt_xml/

# %%
# --- 8. Export for Metamodeling (13,000 points) ---
import pandas as pd
import numpy as np

print("Collecte des résultats et fusion avec le plan d'expérience (13,000 points)...")

_records = []
parc_to_idx = {p: k for k, p in enumerate(ALL_PARCELLES)}

for nom_simu, out_dir in results.items():
    if not (out_dir and out_dir.exists()): continue
    sim_idx = int(nom_simu.split('_')[-1])
    
    df = read_simulation_outputs(out_dir)
    if df.empty: continue
    
    # Mapper chaque parcelle à son point DOE spécifique
    df['point_idx'] = sim_idx * len(ALL_PARCELLES) + df['parcelle'].map(parc_to_idx)
    
    # Calculer la moyenne par parcelle (sur les années de simulation) pour N_lixi, dCorg, rdt
    df_parc = df.groupby(['parcelle', 'point_idx', 'zone', 'sol_type']).agg({
        'N_lixi': 'mean', 'dCorg': 'mean', 'rdt': 'mean'
    }).reset_index()
    
    _records.append(df_parc)

if _records:
    df_full = pd.concat(_records, ignore_index=True)
    
    # Ajouter les caractéristiques agricoles (x0...x25) depuis xt
    # xt contient les 13,000 points
    point_indices = df_full['point_idx'].values
    xt_subset = xt[point_indices]
    
    for j in range(xt.shape[1]):
        df_full[f'feat_{j}'] = xt_subset[:, j]
    
    # Ajout des milieux agrégés (Climat / Sol)
    zone_map = {z: i for i, z in enumerate(sorted(df_full['zone'].unique()))}
    soil_map = {s: i for i, s in enumerate(sorted(df_full['sol_type'].unique()))}
    
    df_full['Milieu (Climat)'] = df_full['zone'].map(zone_map)
    df_full['Milieu (Sol)']    = df_full['sol_type'].map(soil_map)
    
    # Réorganiser les colonnes pour les métamodèles (26 agri + 2 env + 3 outputs)
    X_agri_names = [f'feat_{j}' for j in range(26)]
    export_cols = X_agri_names + ['Milieu (Climat)', 'Milieu (Sol)', 'N_lixi', 'dCorg', 'rdt', 'point_idx', 'parcelle']
    
    df_export = df_full[export_cols]
    export_path = XML_DIR / 'dataset_metamodel.csv'
    df_export.to_csv(export_path, index=False)

    feature_manifest = pd.DataFrame({
        'colonne': X_agri_names,
        'parametre': SMT_FEATURES[:len(X_agri_names)],
    })
    feature_manifest.to_csv(XML_DIR / 'dataset_metamodel_features.csv', index=False)
    
    print(f"Export réussi : {export_path}")
    print(f"Nombre de points : {len(df_export)}")
    print(f"Structure : 26 agri + 2 env + 3 sorties")
else:
    print("Aucune donnée collectée.")
# Out:
# Collecte des résultats et fusion avec le plan d'expérience (13,000 points)...
# Export réussi : /tmp/maelia_smt_xml/dataset_metamodel.csv
# Nombre de points : 34
# Structure : 26 agri + 2 env + 3 sorties

# %% [markdown]
# # ─── SECTION 6: ANALYSE DE SENSIBILITÉ GLOBALE ───────────────────────────────
#
# Cette section réalise une analyse statistique rigoureuse sur le jeu de données complet de **13 000 points** (100 simulations × 130 parcelles).
#
# ### Méthodologie :
# 1. **Agrégation environnementale** : Les zones climatiques et types de sols sont regroupés en deux paramètres interpretables : *Milieu (Climat)* et *Milieu (Sol)*.
# 2. **ANOVA (η²)** : Mesure la variance expliquée par chaque facteur (via Kruskal-Wallis).
# 3. **PRCC** : Corrélations partielles de rang (gère les non-linéarités et les interactions).
# 4. **Sobol S1** : Estimation des indices de premier ordre (sensibilité directe).

# %%
import scipy.stats as _stats
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# ============================================================
# 1. Reconstruction propre des paramètres depuis SMT/ADSG
# ============================================================

def build_clean_parameter_table(x_array, dsg_space):
    """
    Reconstruit un tableau propre des paramètres explorés.
    Les variables inactives sont mises à NaN.
    On n'utilise donc plus directement x0...x25.
    """

    rows = []
    decoded_data = dsg_space.decode_values(x_array)

    for row_data in decoded_data:
        p = parse_smt_row(row_data)
        fl = p["floats"]

        n_ferti = p["n_ferti"]
        has_prepa = p["has_prepa"]

        row = {
            # Structure globale
            "n_ferti": n_ferti,
            "has_prepa": "Oui" if has_prepa else "Non",

            # Préparation
            "nb_prepa": p["nb_prepa"] if has_prepa else np.nan,
            "prepa_1": p["prepa_t1"] if has_prepa else np.nan,
            "prepa_2": p["prepa_t2"] if has_prepa and p["nb_prepa"] == 2 else np.nan,

            # Fertilisation 1
            "nb_f1": p["nb_f1"] if n_ferti >= 1 else np.nan,
            "type_f1_1": p["f1_t1"] if n_ferti >= 1 else np.nan,
            "type_f1_2": p["f1_t2"] if n_ferti >= 1 and p["nb_f1"] == 2 else np.nan,

            # Fertilisation 2
            "nb_f2": p["nb_f2"] if n_ferti >= 2 else np.nan,
            "type_f2_1": p["f2_t1"] if n_ferti >= 2 else np.nan,
            "type_f2_2": p["f2_t2"] if n_ferti >= 2 and p["nb_f2"] == 2 else np.nan,

            # Fertilisation 3
            "nb_f3": p["nb_f3"] if n_ferti >= 3 else np.nan,
            "type_f3_1": p["f3_t1"] if n_ferti >= 3 else np.nan,
            "type_f3_2": p["f3_t2"] if n_ferti >= 3 and p["nb_f3"] == 2 else np.nan,

            # Variables continues
            "Date_Semis": fl[0],

            "Delta_PREPA_Semis": fl[1] if has_prepa else np.nan,

            "Date_F1": fl[2] if n_ferti >= 1 else np.nan,
            "Date_F2": fl[3] if n_ferti >= 2 else np.nan,
            "Date_F3": fl[4] if n_ferti >= 3 else np.nan,
            "Date_Recolte": fl[5],

            "Dose_F1_1": fl[6] if n_ferti >= 1 else np.nan,
            "Dose_F1_2": fl[7] if n_ferti >= 1 and p["nb_f1"] == 2 else np.nan,

            "Dose_F2_1": fl[8] if n_ferti >= 2 else np.nan,
            "Dose_F2_2": fl[9] if n_ferti >= 2 and p["nb_f2"] == 2 else np.nan,

            "Dose_F3_1": fl[10] if n_ferti >= 3 else np.nan,
            "Dose_F3_2": fl[11] if n_ferti >= 3 and p["nb_f3"] == 2 else np.nan,
        }

        rows.append(row)

    return pd.DataFrame(rows)


# ============================================================
# 2. Préparation du dataset complet
# ============================================================

print("Aggregating data points for rigorous ANOVA/Kruskal analysis...")

if "_records" in globals() and _records:

    df_full = pd.concat(_records, ignore_index=True)

    # Tableau propre des paramètres, un par point du plan SMT
    params_by_point = build_clean_parameter_table(xt, agri_design_space)

    # Expansion vers les lignes de simulation
    params_expanded = params_by_point.iloc[df_full["point_idx"].values].reset_index(drop=True)

    # Fusion résultats MAELIA + paramètres propres
    df_full = pd.concat(
        [
            df_full.reset_index(drop=True),
            params_expanded.reset_index(drop=True)
        ],
        axis=1
    )

    # Variables environnementales comme facteurs catégoriels
    df_full["Milieu (Climat)"] = df_full["zone"].astype(str)
    df_full["Milieu (Sol)"] = df_full["sol_type"].astype(str)
    df_full["Milieu (Climat x Sol)"] = (
        df_full["zone"].astype(str) + " x " + df_full["sol_type"].astype(str)
    )

    print(f"Dataset: {len(df_full)} rows")
    print(f"Number of design points: {len(params_by_point)}")

    # ============================================================
    # 3. Métadonnées des variables
    # ============================================================

    VARIABLES = [
        {"col": "n_ferti", "label": "n_ferti", "type": "ordinal"},
        {"col": "has_prepa", "label": "has_prepa", "type": "categorical"},

        {"col": "nb_prepa", "label": "nb_prepa", "type": "ordinal"},
        {"col": "prepa_1", "label": "prepa_1", "type": "categorical"},
        {"col": "prepa_2", "label": "prepa_2", "type": "categorical"},

        {"col": "nb_f1", "label": "nb_f1", "type": "ordinal"},
        {"col": "type_f1_1", "label": "type_f1_1", "type": "categorical"},
        {"col": "type_f1_2", "label": "type_f1_2", "type": "categorical"},

        {"col": "nb_f2", "label": "nb_f2", "type": "ordinal"},
        {"col": "type_f2_1", "label": "type_f2_1", "type": "categorical"},
        {"col": "type_f2_2", "label": "type_f2_2", "type": "categorical"},

        {"col": "nb_f3", "label": "nb_f3", "type": "ordinal"},
        {"col": "type_f3_1", "label": "type_f3_1", "type": "categorical"},
        {"col": "type_f3_2", "label": "type_f3_2", "type": "categorical"},

        {"col": "Date_Semis", "label": "Date_Semis", "type": "continuous"},
        {"col": "Delta_PREPA_Semis", "label": "Delta_PREPA_Semis", "type": "continuous"},
        {"col": "Date_F1", "label": "Date_F1", "type": "continuous"},
        {"col": "Date_F2", "label": "Date_F2", "type": "continuous"},
        {"col": "Date_F3", "label": "Date_F3", "type": "continuous"},
        {"col": "Date_Recolte", "label": "Date_Recolte", "type": "continuous"},

        {"col": "Dose_F1_1", "label": "Dose_F1_1", "type": "continuous"},
        {"col": "Dose_F1_2", "label": "Dose_F1_2", "type": "continuous"},
        {"col": "Dose_F2_1", "label": "Dose_F2_1", "type": "continuous"},
        {"col": "Dose_F2_2", "label": "Dose_F2_2", "type": "continuous"},
        {"col": "Dose_F3_1", "label": "Dose_F3_1", "type": "continuous"},
        {"col": "Dose_F3_2", "label": "Dose_F3_2", "type": "continuous"},

        {"col": "Milieu (Climat)", "label": "Milieu (Climat)", "type": "categorical"},
        {"col": "Milieu (Sol)", "label": "Milieu (Sol)", "type": "categorical"},
        {"col": "Milieu (Climat x Sol)", "label": "Milieu (Climat x Sol)", "type": "categorical"},
    ]

    OUTPUTS = ["N_lixi", "dCorg", "rdt"]

    N_QUANTILE_BINS = 4
    MIN_GROUP_SIZE = 5
    MIN_TOTAL_N = 30

    # ============================================================
    # 4. Fonctions statistiques
    # ============================================================

    def make_groups_for_variable(df, var, output_col):
        col = var["col"]
        var_type = var["type"]

        sub = df[[col, output_col]].dropna().copy()

        if len(sub) < MIN_TOTAL_N:
            return None, sub, None

        if var_type == "continuous":
            try:
                sub["_group"] = pd.qcut(
                    sub[col],
                    q=N_QUANTILE_BINS,
                    duplicates="drop"
                )
                sub["_group"] = sub["_group"].cat.remove_unused_categories()
            except ValueError:
                return None, sub, None

        else:
            sub["_group"] = sub[col].astype(str)

        counts = sub["_group"].value_counts()
        valid_groups = counts[counts >= MIN_GROUP_SIZE].index
        sub = sub[sub["_group"].isin(valid_groups)].copy()

        if var_type == "continuous" and hasattr(sub["_group"], "cat"):
            sub["_group"] = sub["_group"].cat.remove_unused_categories()

        if sub["_group"].nunique() < 2:
            return None, sub, None

        group_counts = sub["_group"].value_counts()

        groups = [
            g[output_col].values
            for _, g in sub.groupby("_group", observed=True)
        ]

        return groups, sub, group_counts

    def kruskal_effect_size(groups):
        k = len(groups)
        n = sum(len(g) for g in groups)

        if k < 2 or n <= k:
            return np.nan, np.nan

        try:
            h_stat, p_value = _stats.kruskal(*groups)

            # Epsilon squared de Kruskal-Wallis
            eps2 = (h_stat - k + 1) / (n - k)
            eps2 = max(0.0, min(1.0, eps2))

            return eps2, p_value

        except Exception:
            return np.nan, np.nan

    def group_r2_from_sub(sub, output_col):
        y = sub[output_col].values
        y_mean = np.mean(y)
        ss_total = np.sum((y - y_mean) ** 2)

        if ss_total <= 1e-12:
            return np.nan

        ss_between = 0.0

        for _, g in sub.groupby("_group", observed=True):
            yg = g[output_col].values
            ss_between += len(yg) * (np.mean(yg) - y_mean) ** 2

        r2 = ss_between / ss_total
        return max(0.0, min(1.0, r2))

    def benjamini_hochberg(p_values):
        p_values = np.asarray(p_values, dtype=float)
        q_values = np.full_like(p_values, np.nan)

        valid = ~np.isnan(p_values)
        p = p_values[valid]

        if len(p) == 0:
            return q_values

        order = np.argsort(p)
        ranked_p = p[order]
        m = len(p)

        ranked_q = ranked_p * m / (np.arange(1, m + 1))
        ranked_q = np.minimum.accumulate(ranked_q[::-1])[::-1]
        ranked_q = np.minimum(ranked_q, 1.0)

        q = np.empty_like(p)
        q[order] = ranked_q
        q_values[valid] = q

        return q_values

    # ============================================================
    # 5. Calcul ANOVA/Kruskal
    # ============================================================

    all_results = []

    for output_col in OUTPUTS:
        if output_col not in df_full.columns:
            continue

        df_out = df_full.dropna(subset=[output_col]).copy()

        for var in VARIABLES:
            groups, sub, group_counts = make_groups_for_variable(df_out, var, output_col)

            if groups is None:
                all_results.append({
                    "output": output_col,
                    "variable": var["label"],
                    "column": var["col"],
                    "type": var["type"],
                    "n_used": len(sub),
                    "n_groups": 0 if group_counts is None else len(group_counts),
                    "min_group_size": np.nan if group_counts is None or len(group_counts) == 0 else int(group_counts.min()),
                    "max_group_size": np.nan if group_counts is None or len(group_counts) == 0 else int(group_counts.max()),
                    "kruskal_epsilon2": np.nan,
                    "group_r2": np.nan,
                    "p_value": np.nan,
                })
                continue

            eps2, p_value = kruskal_effect_size(groups)
            r2_group = group_r2_from_sub(sub, output_col)

            all_results.append({
                "output": output_col,
                "variable": var["label"],
                "column": var["col"],
                "type": var["type"],
                "n_used": len(sub),
                "n_groups": sub["_group"].nunique(),
                "min_group_size": int(sub["_group"].value_counts().min()),
                "max_group_size": int(sub["_group"].value_counts().max()),
                "kruskal_epsilon2": eps2,
                "group_r2": r2_group,
                "p_value": p_value,
            })

    results_df = pd.DataFrame(all_results)

    results_df["q_value_fdr"] = np.nan

    for output_col in results_df["output"].dropna().unique():
        mask = results_df["output"] == output_col
        results_df.loc[mask, "q_value_fdr"] = benjamini_hochberg(
            results_df.loc[mask, "p_value"].values
        )

    results_df_sorted = results_df.sort_values(
        ["output", "kruskal_epsilon2"],
        ascending=[True, False]
    )

    print("ANOVA/Kruskal results table:")
    display(results_df_sorted)

    # ============================================================
    # 6. Graphique final
    # ============================================================

    plot_outputs = [o for o in OUTPUTS if o in results_df["output"].unique()]

    if plot_outputs:
        fig, axes = plt.subplots(
            1,
            len(plot_outputs),
            figsize=(7 * len(plot_outputs), 10),
            sharey=True
        )

        if len(plot_outputs) == 1:
            axes = [axes]

        ordered_labels = [v["label"] for v in VARIABLES]

        for ax, output_col in zip(axes, plot_outputs):
            subres = results_df[results_df["output"] == output_col].copy()
            subres = subres.set_index("variable").reindex(ordered_labels).reset_index()

            y_pos = np.arange(len(subres))
            vals = subres["kruskal_epsilon2"].fillna(0.0).values

            ax.barh(
                y_pos,
                vals,
                color="skyblue",
                edgecolor="navy",
                alpha=0.8
            )

            ax.set_yticks(y_pos)
            ax.set_yticklabels(subres["variable"], fontsize=9)
            ax.set_xlabel("Kruskal ε²", fontsize=10)
            ax.set_title(output_col, fontsize=11, fontweight="bold")
            ax.invert_yaxis()
            ax.grid(axis="x", linestyle="--", alpha=0.5)

            x_max = max(float(np.nanmax(vals)), 0.01)
            ax.set_xlim(0, x_max * 1.90)

            for i, row in subres.iterrows():
                eps2 = row["kruskal_epsilon2"]
                r2 = row["group_r2"]
                q = row["q_value_fdr"]
                n_used = row["n_used"]

                if np.isnan(eps2):
                    label = "NA"
                    x_text = x_max * 0.01
                else:
                    sig = ""
                    if not np.isnan(q):
                        if q < 0.001:
                            sig = "***"
                        elif q < 0.01:
                            sig = "**"
                        elif q < 0.05:
                            sig = "*"

                    label = f"R²grp={r2:.3f}, n={int(n_used)} {sig}"
                    x_text = eps2 + x_max * 0.02

                ax.text(
                    x_text,
                    i,
                    label,
                    va="center",
                    ha="left",
                    fontsize=8
                )

        plt.suptitle(
            "Analyse ANOVA/Kruskal sur paramètres décodés et actifs",
            fontsize=14,
            y=1.02
        )

        plt.tight_layout()
        plt.show()

else:
    print("No simulation records found. Run the simulation collection cell first.")
# Out:
# Aggregating data points for rigorous ANOVA/Kruskal analysis...
# Dataset: 34 rows
# Number of design points: 100
# ANOVA/Kruskal results table:
#     output               variable                 column         type  n_used  \
# 0   N_lixi                n_ferti                n_ferti      ordinal      34
# 1   N_lixi              has_prepa              has_prepa  categorical      34
# 2   N_lixi               nb_prepa               nb_prepa      ordinal      15
# 3   N_lixi                prepa_1                prepa_1  categorical      15
# 4   N_lixi                prepa_2                prepa_2  categorical      10
# ..     ...                    ...                    ...          ...     ...
# 82     rdt              Dose_F3_1              Dose_F3_1   continuous      11
# 83     rdt              Dose_F3_2              Dose_F3_2   continuous       6
# 84     rdt        Milieu (Climat)        Milieu (Climat)  categorical      34
# 85     rdt           Milieu (Sol)           Milieu (Sol)  categorical      34
# 86     rdt  Milieu (Climat x Sol)  Milieu (Climat x Sol)  categorical      34
#
#     n_groups  min_group_size  max_group_size  kruskal_epsilon2  group_r2  \
# 0          4             5.0            11.0               NaN       NaN
# 1          2            15.0            19.0               NaN       NaN
# 2          0             NaN             NaN               NaN       NaN
# 3          0             NaN             NaN               NaN       NaN
# 4          0             NaN             NaN               NaN       NaN
# ..       ...             ...             ...               ...       ...
# 82         0             NaN             NaN               NaN       NaN
# 83         0             NaN             NaN               NaN       NaN
# 84         0             NaN             NaN               NaN       NaN
# 85         0             NaN             NaN               NaN       NaN
# 86         0             NaN             NaN               NaN       NaN
#
#     p_value  q_value_fdr
# 0       NaN          NaN
# 1       NaN          NaN
# 2       NaN          NaN
# 3       NaN          NaN
# 4       NaN          NaN
# ..      ...          ...
# 82      NaN          NaN
# 83      NaN          NaN
# 84      NaN          NaN
# 85      NaN          NaN
# 86      NaN          NaN
#
# [87 rows x 12 columns]
